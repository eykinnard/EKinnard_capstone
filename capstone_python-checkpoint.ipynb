# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %matplotlib inline

# %%
water_temp_1955_spring = pd.read_csv('../data/1955_1964_water_temp_spring.csv')
water_temp_1955_spring
# Out:
#      #COMMA SEPARATED LATITUDE   LONGITUDE   AND VALUES AT DEPTHS (M):0  \
# 0                         17.5       -85.5                       27.080
# 1                         17.5       -84.5                       28.301
# 2                         17.5       -82.5                       29.301
# 3                         17.5       -81.5                       28.195
# 4                         17.5       -78.5                       28.801
# ..                         ...         ...                          ...
# 177                       32.5       -78.5                       24.696
# 178                       32.5       -77.5                       25.286
# 179                       32.5       -76.5                       24.917
# 180                       33.5       -77.5                       20.790
# 181                       33.5       -76.5                       24.405
#
#           5      10      15      20      25      30      35  ...  4600  4700  \
# ...

# %%
water_temp_1955 = water_temp_1955_spring[['#COMMA SEPARATED LATITUDE', ' LONGITUDE', '5']]
water_temp_1955.columns = ['latitude', 'longitude', '5_meters']
water_temp_1955['year'] = '1955'
water_temp_1955.reset_index(drop = True)
# Out:
# C:\Users\eykin\AppData\Local\Temp\ipykernel_38084\3861436122.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   water_temp_1955['year'] = '1955'
#      latitude  longitude  5_meters  year
# 0        17.5      -85.5    27.020  1955
# 1        17.5      -84.5    28.149  1955
# 2        17.5      -82.5    29.249  1955
# 3        17.5      -81.5    28.155  1955
# 4        17.5      -78.5       NaN  1955
# ..        ...        ...       ...   ...
# 177      32.5      -78.5    24.529  1955
# 178      32.5      -77.5    25.158  1955
# 179      32.5      -76.5    24.865  1955
# 180      33.5      -77.5    20.507  1955
# 181      33.5      -76.5    24.327  1955
#
# [182 rows x 4 columns]

# %%
water_temp_1955 = water_temp_1955.loc[(water_temp_1955.latitude == 29.5)& (water_temp_1955.longitude == -87.5)]
water_temp_1955
# Out:
#      latitude  longitude  5_meters  year
# 159      29.5      -87.5    25.815  1955

# %%
water_temp_1955_summer = pd.read_csv('../data/1955_1964_water_temp_summer.csv')
water_temp_1955_summer
# Out:
#      #COMMA SEPARATED LATITUDE   LONGITUDE   AND VALUES AT DEPTHS (M):0  \
# 0                         17.5       -87.5                       28.499
# 1                         17.5       -85.5                       27.801
# 2                         17.5       -84.5                       29.574
# 3                         17.5       -83.5                       27.669
# 4                         17.5       -79.5                       28.967
# ..                         ...         ...                          ...
# 169                       32.5       -78.5                       28.362
# 170                       32.5       -77.5                       29.478
# 171                       32.5       -76.5                       28.199
# 172                       33.5       -77.5                       27.671
# 173                       33.5       -76.5                       28.292
#
#           5      10      15      20      25      30      35  ...  4600  4700  \
# ...

# %%
water_temp_1955_sum = water_temp_1955_summer[['#COMMA SEPARATED LATITUDE', ' LONGITUDE', '5']]
water_temp_1955_sum.columns = ['latitude', 'longitude', '5_meters']
water_temp_1955_sum['year'] = '1955'
water_temp_1955_sum.reset_index(drop = True)
# Out:
# C:\Users\eykin\AppData\Local\Temp\ipykernel_38084\2707115751.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   water_temp_1955_sum['year'] = '1955'
#      latitude  longitude  5_meters  year
# 0        17.5      -87.5    28.435  1955
# 1        17.5      -85.5    27.783  1955
# 2        17.5      -84.5    29.500  1955
# 3        17.5      -83.5    27.634  1955
# 4        17.5      -79.5    28.965  1955
# ..        ...        ...       ...   ...
# 169      32.5      -78.5    28.317  1955
# 170      32.5      -77.5    29.420  1955
# 171      32.5      -76.5    28.149  1955
# 172      33.5      -77.5    26.795  1955
# 173      33.5      -76.5    28.220  1955
#
# [174 rows x 4 columns]

# %%
water_temp_1955_sum = water_temp_1955_sum.loc[(water_temp_1955_sum.latitude == 29.5)& (water_temp_1955_sum.longitude == -87.5)]
water_temp_1955_sum
# Out:
#      latitude  longitude  5_meters  year
# 151      29.5      -87.5    28.962  1955

# %%
water_temp_1965_spring = pd.read_csv('../data/1965-1974_water_temp_spring.csv')
water_temp_1965_spring
# Out:
#      #COMMA SEPARATED LATITUDE   LONGITUDE   AND VALUES AT DEPTHS (M):0  \
# 0                         17.5       -87.5                       27.346
# 1                         17.5       -86.5                       27.219
# 2                         17.5       -85.5                       27.417
# 3                         17.5       -84.5                       27.298
# 4                         17.5       -83.5                       27.380
# ..                         ...         ...                          ...
# 199                       32.5       -78.5                       24.157
# 200                       32.5       -77.5                       25.130
# 201                       32.5       -76.5                       25.320
# 202                       33.5       -77.5                       21.552
# 203                       33.5       -76.5                       24.843
#
#           5      10      15      20      25      30      35  ...  4600   4700  \
# ...

# %%
water_temp_1965 = water_temp_1965_spring[['#COMMA SEPARATED LATITUDE', ' LONGITUDE', '5']]
water_temp_1965.columns = ['latitude', 'longitude', '5_meters']
water_temp_1965['year'] = '1965'
water_temp_1965.reset_index(drop = True)
# Out:
# C:\Users\eykin\AppData\Local\Temp\ipykernel_38084\3511555826.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   water_temp_1965['year'] = '1965'
#      latitude  longitude  5_meters  year
# 0        17.5      -87.5    27.297  1965
# 1        17.5      -86.5    27.180  1965
# 2        17.5      -85.5    27.394  1965
# 3        17.5      -84.5    27.266  1965
# 4        17.5      -83.5    27.348  1965
# ..        ...        ...       ...   ...
# 199      32.5      -78.5    24.100  1965
# 200      32.5      -77.5    25.116  1965
# 201      32.5      -76.5    25.416  1965
# 202      33.5      -77.5    21.374  1965
# 203      33.5      -76.5    24.814  1965
#
# [204 rows x 4 columns]

# %%
water_temp_1965 = water_temp_1965.loc[(water_temp_1965.latitude == 29.5)& (water_temp_1965.longitude == -87.5)]
water_temp_1965
# Out:
#      latitude  longitude  5_meters  year
# 180      29.5      -87.5    23.923  1965

# %%
water_temp_1965_summer = pd.read_csv('../data/1965_1974_water_temp_summer.csv')
water_temp_1965_summer
# Out:
#      #COMMA SEPARATED LATITUDE   LONGITUDE   AND VALUES AT DEPTHS (M):0  \
# 0                         17.5       -87.5                       28.289
# 1                         17.5       -86.5                       28.354
# 2                         17.5       -85.5                       28.119
# 3                         17.5       -84.5                       27.836
# 4                         17.5       -83.5                       28.013
# ..                         ...         ...                          ...
# 201                       32.5       -78.5                       27.728
# 202                       32.5       -77.5                       28.153
# 203                       32.5       -76.5                       28.288
# 204                       33.5       -77.5                       26.483
# 205                       33.5       -76.5                       28.015
#
#           5      10      15      20      25      30      35  ...  4600  4700  \
# ...

# %%
water_temp_1965_sum = water_temp_1965_summer[['#COMMA SEPARATED LATITUDE', ' LONGITUDE', '5']]
water_temp_1965_sum.columns = ['latitude', 'longitude', '5_meters']
water_temp_1965_sum['year'] = '1965'
water_temp_1965_sum.reset_index(drop = True)
# Out:
# C:\Users\eykin\AppData\Local\Temp\ipykernel_38084\2228000660.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   water_temp_1965_sum['year'] = '1965'
#      latitude  longitude  5_meters  year
# 0        17.5      -87.5    28.248  1965
# 1        17.5      -86.5    28.306  1965
# 2        17.5      -85.5    28.069  1965
# 3        17.5      -84.5    27.791  1965
# 4        17.5      -83.5    27.956  1965
# ..        ...        ...       ...   ...
# 201      32.5      -78.5    27.644  1965
# 202      32.5      -77.5    28.109  1965
# 203      32.5      -76.5    28.269  1965
# 204      33.5      -77.5    26.327  1965
# 205      33.5      -76.5    27.946  1965
#
# [206 rows x 4 columns]

# %%
water_temp_1965_sum = water_temp_1965_sum.loc[(water_temp_1965_sum.latitude == 28.5)& (water_temp_1965_sum.longitude == -89.5)]
water_temp_1965_sum
# Out:
#      latitude  longitude  5_meters  year
# 171      28.5      -89.5    28.186  1965

# %%
water_temp_1975_spring = pd.read_csv('../data/1975_1984_water_temp_spring.csv')
water_temp_1975_spring
# Out:
#      #COMMA SEPARATED LATITUDE   LONGITUDE   AND VALUES AT DEPTHS (M):0  \
# 0                         17.5       -87.5                       28.099
# 1                         17.5       -86.5                       27.007
# 2                         17.5       -85.5                       27.983
# 3                         17.5       -84.5                       27.748
# 4                         17.5       -83.5                       27.683
# ..                         ...         ...                          ...
# 191                       32.5       -78.5                       24.178
# 192                       32.5       -77.5                       25.266
# 193                       32.5       -76.5                       25.380
# 194                       33.5       -77.5                       23.278
# 195                       33.5       -76.5                       25.349
#
#           5      10      15      20      25      30      35  ...  4600  4700  \
# ...

# %%
water_temp_1975 = water_temp_1975_spring[['#COMMA SEPARATED LATITUDE', ' LONGITUDE', '5']]
water_temp_1975.columns = ['latitude', 'longitude', '5_meters']
water_temp_1975['year'] = '1975'
water_temp_1975.reset_index(drop = True)
# Out:
# C:\Users\eykin\AppData\Local\Temp\ipykernel_38084\2001699280.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   water_temp_1975['year'] = '1975'
#      latitude  longitude  5_meters  year
# 0        17.5      -87.5    28.093  1975
# 1        17.5      -86.5    26.959  1975
# 2        17.5      -85.5    27.894  1975
# 3        17.5      -84.5    27.734  1975
# 4        17.5      -83.5    27.674  1975
# ..        ...        ...       ...   ...
# 191      32.5      -78.5    24.022  1975
# 192      32.5      -77.5    25.231  1975
# 193      32.5      -76.5    25.360  1975
# 194      33.5      -77.5    22.935  1975
# 195      33.5      -76.5    25.398  1975
#
# [196 rows x 4 columns]

# %%
water_temp_1975 = water_temp_1975.loc[(water_temp_1975.latitude == 29.5)& (water_temp_1975.longitude == -87.5)]
water_temp_1975
# Out:
#      latitude  longitude  5_meters  year
# 173      29.5      -87.5    25.512  1975

# %%
water_temp_1975_summer = pd.read_csv('../data/1975_1984_water_temp_summer.csv')
water_temp_1975_summer
# Out:
#      #COMMA SEPARATED LATITUDE   LONGITUDE   AND VALUES AT DEPTHS (M):0  \
# 0                         17.5       -87.5                       28.930
# 1                         17.5       -86.5                       28.490
# 2                         17.5       -85.5                       28.472
# 3                         17.5       -84.5                       28.563
# 4                         17.5       -83.5                       28.464
# ..                         ...         ...                          ...
# 192                       32.5       -78.5                       28.232
# 193                       32.5       -77.5                       28.260
# 194                       32.5       -76.5                       28.377
# 195                       33.5       -77.5                       27.453
# 196                       33.5       -76.5                       28.252
#
#           5      10      15      20      25      30      35  ...  4600  4700  \
# ...

# %%
water_temp_1975_sum = water_temp_1975_summer[['#COMMA SEPARATED LATITUDE', ' LONGITUDE', '5']]
water_temp_1975_sum.columns = ['latitude', 'longitude', '5_meters']
water_temp_1975_sum['year'] = '1975'
water_temp_1975_sum.reset_index(drop = True)
# Out:
# C:\Users\eykin\AppData\Local\Temp\ipykernel_38084\258673265.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   water_temp_1975_sum['year'] = '1975'
#      latitude  longitude  5_meters  year
# 0        17.5      -87.5    28.917  1975
# 1        17.5      -86.5    28.484  1975
# 2        17.5      -85.5    28.462  1975
# 3        17.5      -84.5    28.553  1975
# 4        17.5      -83.5    28.422  1975
# ..        ...        ...       ...   ...
# 192      32.5      -78.5    28.112  1975
# 193      32.5      -77.5    28.243  1975
# 194      32.5      -76.5    28.345  1975
# 195      33.5      -77.5    27.370  1975
# 196      33.5      -76.5    28.198  1975
#
# [197 rows x 4 columns]

# %%
water_temp_1975_sum = water_temp_1975_sum.loc[(water_temp_1975_sum.latitude == 28.5)& (water_temp_1975_sum.longitude == -89.5)]
water_temp_1975_sum
# Out:
#      latitude  longitude  5_meters  year
# 162      28.5      -89.5    29.274  1975

# %%
water_temp_1985_spring = pd.read_csv('../data/1985_1994_water_temp_spring.csv')
water_temp_1985_spring
# Out:
#      #COMMA SEPARATED LATITUDE   LONGITUDE   AND VALUES AT DEPTHS (M):0  \
# 0                         17.5       -87.5                       27.963
# 1                         17.5       -86.5                       27.901
# 2                         17.5       -85.5                       27.610
# 3                         17.5       -84.5                       27.672
# 4                         17.5       -83.5                       27.567
# ..                         ...         ...                          ...
# 184                       32.5       -78.5                       24.203
# 185                       32.5       -77.5                       25.231
# 186                       32.5       -76.5                       25.434
# 187                       33.5       -77.5                       23.011
# 188                       33.5       -76.5                       25.108
#
#           5      10      15      20      25      30      35  ...  4600  4700  \
# ...

# %%
water_temp_1985 = water_temp_1985_spring[['#COMMA SEPARATED LATITUDE', ' LONGITUDE', '5']]
water_temp_1985.columns = ['latitude', 'longitude', '5_meters']
water_temp_1985['year'] = '1985'
water_temp_1985.reset_index(drop = True)
# Out:
# C:\Users\eykin\AppData\Local\Temp\ipykernel_38084\279324402.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   water_temp_1985['year'] = '1985'
#      latitude  longitude  5_meters  year
# 0        17.5      -87.5    27.938  1985
# 1        17.5      -86.5    27.933  1985
# 2        17.5      -85.5    27.604  1985
# 3        17.5      -84.5    27.668  1985
# 4        17.5      -83.5    27.542  1985
# ..        ...        ...       ...   ...
# 184      32.5      -78.5    24.125  1985
# 185      32.5      -77.5    25.198  1985
# 186      32.5      -76.5    25.419  1985
# 187      33.5      -77.5    22.729  1985
# 188      33.5      -76.5    25.073  1985
#
# [189 rows x 4 columns]

# %%
water_temp_1985 = water_temp_1985.loc[(water_temp_1985.latitude == 29.5)& (water_temp_1985.longitude == -87.5)]
water_temp_1985
# Out:
#      latitude  longitude  5_meters  year
# 166      29.5      -87.5    23.956  1985

# %%
water_temp_1985_summer = pd.read_csv('../data/1985_1994_water_temp_summer.csv')
water_temp_1985_summer
# Out:
#      #COMMA SEPARATED LATITUDE   LONGITUDE   AND VALUES AT DEPTHS (M):0  \
# 0                         17.5       -87.5                       28.903
# 1                         17.5       -86.5                       28.687
# 2                         17.5       -85.5                       28.597
# 3                         17.5       -84.5                       28.695
# 4                         17.5       -83.5                       28.572
# ..                         ...         ...                          ...
# 190                       32.5       -78.5                       28.005
# 191                       32.5       -77.5                       28.497
# 192                       32.5       -76.5                       28.574
# 193                       33.5       -77.5                       28.031
# 194                       33.5       -76.5                       28.777
#
#           5      10      15      20      25      30      35  ...  4600  4700  \
# ...

# %%
water_temp_1985_sum = water_temp_1985_summer[['#COMMA SEPARATED LATITUDE', ' LONGITUDE', '5']]
water_temp_1985_sum.columns = ['latitude', 'longitude', '5_meters']
water_temp_1985_sum['year'] = '1985'
water_temp_1985_sum.reset_index(drop = True)
# Out:
# C:\Users\eykin\AppData\Local\Temp\ipykernel_38084\1943958094.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   water_temp_1985_sum['year'] = '1985'
#      latitude  longitude  5_meters  year
# 0        17.5      -87.5    28.930  1985
# 1        17.5      -86.5    28.668  1985
# 2        17.5      -85.5    28.591  1985
# 3        17.5      -84.5    28.728  1985
# 4        17.5      -83.5    28.595  1985
# ..        ...        ...       ...   ...
# 190      32.5      -78.5    27.879  1985
# 191      32.5      -77.5    28.492  1985
# 192      32.5      -76.5    28.597  1985
# 193      33.5      -77.5    27.953  1985
# 194      33.5      -76.5    28.737  1985
#
# [195 rows x 4 columns]

# %%
water_temp_1985_sum = water_temp_1985_sum.loc[(water_temp_1985_sum.latitude == 28.5)& (water_temp_1985_sum.longitude == -89.5)]
water_temp_1985_sum
# Out:
#      latitude  longitude  5_meters  year
# 160      28.5      -89.5    29.369  1985

# %%
water_temp_1995_spring = pd.read_csv('../data/1995_2004_water_temp_spring.csv')
water_temp_1995_spring
# Out:
#      #COMMA SEPARATED LATITUDE   LONGITUDE   AND VALUES AT DEPTHS (M):0  \
# 0                         17.5       -86.5                       26.885
# 1                         17.5       -85.5                       27.950
# 2                         17.5       -84.5                       27.850
# 3                         17.5       -83.5                       27.196
# 4                         17.5       -82.5                       28.033
# ..                         ...         ...                          ...
# 174                       32.5       -78.5                       24.875
# 175                       32.5       -77.5                       26.154
# 176                       32.5       -76.5                       25.628
# 177                       33.5       -77.5                       22.205
# 178                       33.5       -76.5                       25.009
#
#           5      10      15      20      25      30      35  ...  4600  4700  \
# ...

# %%
water_temp_1995 = water_temp_1995_spring[['#COMMA SEPARATED LATITUDE', ' LONGITUDE', '5']]
water_temp_1995.columns = ['latitude', 'longitude', '5_meters']
water_temp_1995['year'] = '1995'
water_temp_1995.reset_index(drop = True)
# Out:
# C:\Users\eykin\AppData\Local\Temp\ipykernel_38084\2206668019.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   water_temp_1995['year'] = '1995'
#      latitude  longitude  5_meters  year
# 0        17.5      -86.5       NaN  1995
# 1        17.5      -85.5    27.905  1995
# 2        17.5      -84.5    27.815  1995
# 3        17.5      -83.5    27.834  1995
# 4        17.5      -82.5    27.913  1995
# ..        ...        ...       ...   ...
# 174      32.5      -78.5    24.870  1995
# 175      32.5      -77.5    26.188  1995
# 176      32.5      -76.5    25.729  1995
# 177      33.5      -77.5    22.266  1995
# 178      33.5      -76.5    25.067  1995
#
# [179 rows x 4 columns]

# %%
water_temp_1995 = water_temp_1995.loc[(water_temp_1995.latitude == 29.5)& (water_temp_1995.longitude == -87.5)]
water_temp_1995
# Out:
#      latitude  longitude  5_meters  year
# 155      29.5      -87.5    24.338  1995

# %%
water_temp_1995_summer = pd.read_csv('../data/1995_2004_water_temp_summer.csv')
water_temp_1995_summer
# Out:
#      #COMMA SEPARATED LATITUDE   LONGITUDE   AND VALUES AT DEPTHS (M):0  \
# 0                         17.5       -87.5                       29.379
# 1                         17.5       -86.5                       29.435
# 2                         17.5       -85.5                       29.546
# 3                         17.5       -82.5                          NaN
# 4                         17.5       -81.5                       29.113
# ..                         ...         ...                          ...
# 134                       32.5       -78.5                       28.153
# 135                       32.5       -77.5                       28.550
# 136                       32.5       -76.5                       28.400
# 137                       33.5       -77.5                       28.019
# 138                       33.5       -76.5                       28.631
#
#           5      10      15      20      25      30      35  ...  4600  4700  \
# ...

# %%
water_temp_1995_sum = water_temp_1995_summer[['#COMMA SEPARATED LATITUDE', ' LONGITUDE', '5']]
water_temp_1995_sum.columns = ['latitude', 'longitude', '5_meters']
water_temp_1995_sum['year'] = '1995'
water_temp_1995_sum.reset_index(drop = True)
# Out:
# C:\Users\eykin\AppData\Local\Temp\ipykernel_38084\3714259985.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   water_temp_1995_sum['year'] = '1995'
#      latitude  longitude  5_meters  year
# 0        17.5      -87.5    29.367  1995
# 1        17.5      -86.5    29.435  1995
# 2        17.5      -85.5    29.535  1995
# 3        17.5      -82.5       NaN  1995
# 4        17.5      -81.5    29.225  1995
# ..        ...        ...       ...   ...
# 134      32.5      -78.5    28.183  1995
# 135      32.5      -77.5    28.519  1995
# 136      32.5      -76.5    28.418  1995
# 137      33.5      -77.5    28.055  1995
# 138      33.5      -76.5    28.651  1995
#
# [139 rows x 4 columns]

# %%
water_temp_1995_sum = water_temp_1995_sum.loc[(water_temp_1995_sum.latitude == 28.5)& (water_temp_1995_sum.longitude == -89.5)]
water_temp_1995_sum
# Out:
#      latitude  longitude  5_meters  year
# 104      28.5      -89.5    29.474  1995

# %%
water_temp_2005_spring = pd.read_csv('../data/2005_2017_water_temp_spring.csv')
water_temp_2005_spring
# Out:
#      #COMMA SEPARATED LATITUDE   LONGITUDE   AND VALUES AT DEPTHS (M):0  \
# 0                         17.5       -87.5                       27.746
# 1                         17.5       -86.5                       27.587
# 2                         17.5       -85.5                       28.585
# 3                         17.5       -84.5                       27.405
# 4                         17.5       -83.5                       27.635
# ..                         ...         ...                          ...
# 168                       32.5       -78.5                       24.957
# 169                       32.5       -77.5                       25.944
# 170                       32.5       -76.5                       25.696
# 171                       33.5       -77.5                       23.468
# 172                       33.5       -76.5                       25.256
#
#           5      10      15      20      25      30      35  ...  4600  4700  \
# ...

# %%
water_temp_2005 = water_temp_2005_spring[['#COMMA SEPARATED LATITUDE', ' LONGITUDE', '5']]
water_temp_2005.columns = ['latitude', 'longitude', '5_meters']
water_temp_2005['year'] = '2005'
water_temp_2005.reset_index(drop = True)
# Out:
# C:\Users\eykin\AppData\Local\Temp\ipykernel_38084\3189260825.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   water_temp_2005['year'] = '2005'
#      latitude  longitude  5_meters  year
# 0        17.5      -87.5    27.726  2005
# 1        17.5      -86.5    27.587  2005
# 2        17.5      -85.5    28.564  2005
# 3        17.5      -84.5    27.405  2005
# 4        17.5      -83.5    27.615  2005
# ..        ...        ...       ...   ...
# 168      32.5      -78.5    25.095  2005
# 169      32.5      -77.5    25.941  2005
# 170      32.5      -76.5    25.692  2005
# 171      33.5      -77.5    23.421  2005
# 172      33.5      -76.5    25.335  2005
#
# [173 rows x 4 columns]

# %%
water_temp_2005 = water_temp_2005.loc[(water_temp_2005.latitude == 29.5)& (water_temp_2005.longitude == -87.5)]
water_temp_2005
# Out:
#      latitude  longitude  5_meters  year
# 150      29.5      -87.5    24.681  2005

# %%
water_temp_2005_summer = pd.read_csv('../data/2005_2017_water_temp_summer.csv')
water_temp_2005_summer
# Out:
#      #COMMA SEPARATED LATITUDE   LONGITUDE   AND VALUES AT DEPTHS (M):0  \
# 0                         17.5       -87.5                       29.492
# 1                         17.5       -86.5                       29.000
# 2                         17.5       -85.5                       28.700
# 3                         17.5       -84.5                       28.900
# 4                         17.5       -83.5                       29.924
# ..                         ...         ...                          ...
# 177                       32.5       -78.5                       27.954
# 178                       32.5       -77.5                       28.400
# 179                       32.5       -76.5                       28.757
# 180                       33.5       -77.5                       27.191
# 181                       33.5       -76.5                       28.952
#
#           5      10      15      20      25      30      35  ...  4600  4700  \
# ...

# %%
water_temp_2005_sum = water_temp_2005_summer[['#COMMA SEPARATED LATITUDE', ' LONGITUDE', '5']]
water_temp_2005_sum.columns = ['latitude', 'longitude', '5_meters']
water_temp_2005_sum['year'] = '2005'
water_temp_2005_sum.reset_index(drop = True)
# Out:
# C:\Users\eykin\AppData\Local\Temp\ipykernel_38084\3066085551.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   water_temp_2005_sum['year'] = '2005'
#      latitude  longitude  5_meters  year
# 0        17.5      -87.5    29.528  2005
# 1        17.5      -86.5    29.156  2005
# 2        17.5      -85.5    28.763  2005
# 3        17.5      -84.5    28.900  2005
# 4        17.5      -83.5    29.921  2005
# ..        ...        ...       ...   ...
# 177      32.5      -78.5    27.990  2005
# 178      32.5      -77.5    28.420  2005
# 179      32.5      -76.5    28.897  2005
# 180      33.5      -77.5    27.185  2005
# 181      33.5      -76.5    29.093  2005
#
# [182 rows x 4 columns]

# %%
water_temp_2005_sum = water_temp_2005_sum.loc[(water_temp_2005_sum.latitude == 28.5)& (water_temp_2005_sum.longitude == -89.5)]
water_temp_2005_sum
# Out:
#      latitude  longitude  5_meters  year
# 147      28.5      -89.5    29.911  2005

# %%
water_temp_95 = pd.merge(water_temp_2005_sum, water_temp_1995_sum,
        on=['year', 'latitude', 'longitude', '5_meters'], how ='outer')
water_temp_95
# Out:
#    latitude  longitude  5_meters  year
# 0      28.5      -89.5    29.911  2005
# 1      28.5      -89.5    29.474  1995

# %%
water_temp_85 = pd.merge(water_temp_1985_sum, water_temp_1975_sum,
        on=['year', 'latitude', 'longitude', '5_meters'], how ='outer')
water_temp_85
# Out:
#    latitude  longitude  5_meters  year
# 0      28.5      -89.5    29.369  1985
# 1      28.5      -89.5    29.274  1975

# %%
water_temp_65 = pd.merge(water_temp_85, water_temp_1965_sum,
        on=['year', 'latitude', 'longitude', '5_meters'], how ='outer')
water_temp_65
# Out:
#    latitude  longitude  5_meters  year
# 0      28.5      -89.5    29.369  1985
# 1      28.5      -89.5    29.274  1975
# 2      28.5      -89.5    28.186  1965

# %%
water_temp = pd.merge(water_temp_65, water_temp_95,
        on=['year', 'latitude', 'longitude', '5_meters'], how ='outer')
water_temp = water_temp.sort_values(by='year').reset_index(drop = True)
water_temp.columns = ['latitude', 'longitude', 'temperature', 'year']
water_temp
# Out:
#    latitude  longitude  temperature  year
# 0      28.5      -89.5       28.186  1965
# 1      28.5      -89.5       29.274  1975
# 2      28.5      -89.5       29.369  1985
# 3      28.5      -89.5       29.474  1995
# 4      28.5      -89.5       29.911  2005

# %%
water_temp['temperature'] =(water_temp.temperature * 1.8) + 32
water_temp
# Out:
#    latitude  longitude  temperature  year
# 0      28.5      -89.5      82.7348  1965
# 1      28.5      -89.5      84.6932  1975
# 2      28.5      -89.5      84.8642  1985
# 3      28.5      -89.5      85.0532  1995
# 4      28.5      -89.5      85.8398  2005

# %%
water_temp.to_csv('../data/water_temp.csv')

# %%
torn_1950_1989 = pd.read_csv('../data/1950-1989_torn.csv')
torn_1950_1989
# Out:
#        tornado_number  year  month  day        date      time  time_zone  \
# 0                   1  1950      1    3  1950-01-03  11:00:00          3
# 1                   1  1950      1    3  1950-01-03  11:00:00          3
# 2                   1  1950      1    3  1950-01-03  11:10:00          3
# 3                   2  1950      1    3  1950-01-03  11:55:00          3
# 4                   3  1950      1    3  1950-01-03  16:00:00          3
# ...               ...   ...    ...  ...         ...       ...        ...
# 28861             852  1989     11   27  1989-11-27  17:45:00          3
# 28862             853  1989     11   27  1989-11-27  21:35:00          3
# 28863             854  1989     12   12  1989-12-12  09:30:00          3
# 28864             855  1989     12   12  1989-12-12  09:30:00          3
# 28865             856  1989     12   12  1989-12-12  10:15:00          3
#
#       state  state_fips  state_number  ...  length_miles  width  \
# ...

# %%
torn_alley_1950_1989 = torn_1950_1989.loc[(torn_1950_1989.state == 'OK') |(torn_1950_1989.state == 'KS') 
|(torn_1950_1989.state == 'NE') |(torn_1950_1989.state == 'TX') |(torn_1950_1989.state == 'MO') 
|(torn_1950_1989.state == 'IA') | (torn_1950_1989.state == 'SD') |(torn_1950_1989.state == 'MN')].reset_index(drop=True)
torn_alley_1950_1989
# Out:
#        tornado_number  year  month  day        date      time  time_zone  \
# 0                   1  1950      1    3  1950-01-03  11:00:00          3
# 1                   1  1950      1    3  1950-01-03  11:00:00          3
# 2                   5  1950      1   25  1950-01-25  19:30:00          3
# 3                   7  1950      1   26  1950-01-26  18:00:00          3
# 4                   8  1950      2   11  1950-02-11  13:10:00          3
# ...               ...   ...    ...  ...         ...       ...        ...
# 13489             793  1989     10   27  1989-10-27  18:30:00          3
# 13490             794  1989     10   27  1989-10-27  18:40:00          3
# 13491             795  1989     10   29  1989-10-29  16:46:00          3
# 13492             796  1989     10   29  1989-10-29  17:32:00          3
# 13493             846  1989     11   17  1989-11-17  14:50:00          3
#
#       state  state_fips  state_number  ...  length_miles  width  \
# ...

# %%
torn_alley_1950_1989.to_csv('../data/torn_alley_1950_1989.csv')

# %%
torn_water_1965 = torn_alley_1950_1989.loc[(torn_alley_1950_1989.year > 1964)&(torn_alley_1950_1989.year<1975)]
torn_water_1965.reset_index(drop = True)
# Out:
#       tornado_number  year  month  day        date      time  time_zone state  \
# 0                  3  1965      1   21  1965-01-21  23:00:00          3    TX
# 1                  5  1965      1   22  1965-01-22  08:00:00          3    TX
# 2                 20  1965      1   25  1965-01-25  21:50:00          3    MO
# 3                 32  1965      2    9  1965-02-09  15:00:00          3    TX
# 4                 35  1965      2   11  1965-02-11  10:15:00          3    TX
# ...              ...   ...    ...  ...         ...       ...        ...   ...
# 3793             924  1974     10   31  1974-10-31  15:30:00          3    TX
# 3794             925  1974     11    1  1974-11-01  06:45:00          3    TX
# 3795             926  1974     11    2  1974-11-02  22:45:00          3    TX
# 3796             927  1974     11    3  1974-11-03  02:30:00          3    OK
# 3797             928  1974     11    3  1974-11-03  20:00:00          3    OK
#
# ...

# %%
torn_water_1965.to_csv('../data/torn_water_1965.csv')

# %%
torn_water_1975 = torn_alley_1950_1989.loc[(torn_alley_1950_1989.year > 1974)&(torn_alley_1950_1989.year<1985)]
torn_water_1975.reset_index(drop = True)
# Out:
#       tornado_number  year  month  day        date      time  time_zone state  \
# 0                  4  1975      1    9  1975-01-09  22:30:00          3    OK
# 1                  7  1975      1   10  1975-01-10  01:30:00          3    TX
# 2                  8  1975      1   10  1975-01-10  02:00:00          3    TX
# 3                  9  1975      1   10  1975-01-10  03:55:00          3    TX
# 4                 11  1975      1   10  1975-01-10  04:30:00          3    TX
# ...              ...   ...    ...  ...         ...       ...        ...   ...
# 3891             892  1984     11    9  1984-11-09  18:15:00          3    MO
# 3892             904  1984     12   13  1984-12-13  09:45:00          3    TX
# 3893             905  1984     12   31  1984-12-31  10:00:00          3    TX
# 3894             906  1984     12   31  1984-12-31  11:30:00          3    TX
# 3895             907  1984     12   31  1984-12-31  11:40:00          3    TX
#
# ...

# %%
torn_water_1975.to_csv('../data/torn_water_1975.csv')

# %%
torn_water_1985_1 = torn_alley_1950_1989.loc[(torn_alley_1950_1989.year > 1984)]
torn_water_1985_1.reset_index(drop = True)
# Out:
#       tornado_number  year  month  day        date      time  time_zone state  \
# 0                  6  1985      2   22  1985-02-22  02:15:00          3    OK
# 1                  7  1985      2   23  1985-02-23  01:00:00          3    OK
# 2                 10  1985      3    3  1985-03-03  16:35:00          3    NE
# 3                 11  1985      3    3  1985-03-03  17:30:00          3    NE
# 4                 12  1985      3    3  1985-03-03  18:10:00          3    NE
# ...              ...   ...    ...  ...         ...       ...        ...   ...
# 1529             793  1989     10   27  1989-10-27  18:30:00          3    KS
# 1530             794  1989     10   27  1989-10-27  18:40:00          3    KS
# 1531             795  1989     10   29  1989-10-29  16:46:00          3    OK
# 1532             796  1989     10   29  1989-10-29  17:32:00          3    OK
# 1533             846  1989     11   17  1989-11-17  14:50:00          3    TX
#
# ...

# %%
dixie_alley_1950_1989 = torn_1950_1989.loc[(torn_1950_1989.state == 'AR') |(torn_1950_1989.state == 'LA') 
|(torn_1950_1989.state == 'TN') |(torn_1950_1989.state == 'AL') |(torn_1950_1989.state == 'GA') 
|(torn_1950_1989.state == 'MS')].reset_index(drop=True)
dixie_alley_1950_1989
# Out:
#       tornado_number  year  month  day        date      time  time_zone state  \
# 0                  4  1950      1   13  1950-01-13  05:25:00          3    AR
# 1                 16  1950      2   12  1950-02-12  12:00:00          3    MS
# 2                 17  1950      2   12  1950-02-12  12:00:00          3    MS
# 3                 19  1950      2   12  1950-02-12  12:30:00          3    AR
# 4                 20  1950      2   12  1950-02-12  13:00:00          3    LA
# ...              ...   ...    ...  ...         ...       ...        ...   ...
# 4638             818  1989     11   15  1989-11-15  17:55:00          3    AL
# 4639             819  1989     11   15  1989-11-15  18:05:00          3    GA
# 4640             821  1989     11   15  1989-11-15  18:30:00          3    GA
# 4641             822  1989     11   15  1989-11-15  18:45:00          3    TN
# 4642             849  1989     11   22  1989-11-22  15:30:00          3    MS
#
# ...

# %%
dixie_water_1965 = dixie_alley_1950_1989.loc[(dixie_alley_1950_1989.year > 1964)&(dixie_alley_1950_1989.year<1975)]
dixie_water_1965.reset_index(drop = True)
# Out:
#       tornado_number  year  month  day        date      time  time_zone state  \
# 0                  1  1965      1    8  1965-01-08  17:01:00          3    LA
# 1                  4  1965      1   22  1965-01-22  06:15:00          3    LA
# 2                  6  1965      1   22  1965-01-22  10:20:00          3    LA
# 3                  7  1965      1   22  1965-01-22  11:00:00          3    LA
# 4                  8  1965      1   22  1965-01-22  11:00:00          3    LA
# ...              ...   ...    ...  ...         ...       ...        ...   ...
# 1349             934  1974     11   20  1974-11-20  04:30:00          3    LA
# 1350             935  1974     11   20  1974-11-20  06:15:00          3    GA
# 1351             937  1974     11   30  1974-11-30  22:00:00          3    GA
# 1352             943  1974     12   19  1974-12-19  14:04:00          3    AL
# 1353             944  1974     12   19  1974-12-19  16:30:00          3    AL
#
# ...

# %%
dixie_water_1965.to_csv('../data/dixie_water_1965.csv')

# %%
dixie_water_1975 = dixie_alley_1950_1989.loc[(dixie_alley_1950_1989.year > 1974)&(dixie_alley_1950_1989.year<1985)]
dixie_water_1975.reset_index(drop = True)
# Out:
#       tornado_number  year  month  day        date      time  time_zone state  \
# 0                  1  1975      1    7  1975-01-07  15:32:00          3    LA
# 1                  2  1975      1    7  1975-01-07  19:30:00          3    LA
# 2                  5  1975      1    9  1975-01-09  22:40:00          3    LA
# 3                  6  1975      1   10  1975-01-10  00:55:00          3    AR
# 4                 12  1975      1   10  1975-01-10  05:25:00          3    LA
# ...              ...   ...    ...  ...         ...       ...        ...   ...
# 1450             898  1984     11   10  1984-11-10  14:22:00          3    AL
# 1451             899  1984     11   10  1984-11-10  14:30:00          3    TN
# 1452             900  1984     11   10  1984-11-10  15:40:00          3    AL
# 1453             901  1984     11   10  1984-11-10  15:50:00          3    AL
# 1454             902  1984     11   10  1984-11-10  17:50:00          3    GA
#
# ...

# %%
dixie_water_1975.to_csv('../data/dixie_water_1975.csv')

# %%
dixie_water_1985_1 = dixie_alley_1950_1989.loc[(dixie_alley_1950_1989.year > 1984)]
dixie_water_1985_1.reset_index(drop = True)
# Out:
#      tornado_number  year  month  day        date      time  time_zone state  \
# 0                 2  1985      1   31  1985-01-31  16:52:00          3    AL
# 1                 4  1985      2   11  1985-02-11  04:50:00          3    AL
# 2                 8  1985      2   23  1985-02-23  16:05:00          3    MS
# 3                 9  1985      2   23  1985-02-23  16:15:00          3    MS
# 4                51  1985      4    5  1985-04-05  11:05:00          3    LA
# ..              ...   ...    ...  ...         ...       ...        ...   ...
# 588             818  1989     11   15  1989-11-15  17:55:00          3    AL
# 589             819  1989     11   15  1989-11-15  18:05:00          3    GA
# 590             821  1989     11   15  1989-11-15  18:30:00          3    GA
# 591             822  1989     11   15  1989-11-15  18:45:00          3    TN
# 592             849  1989     11   22  1989-11-22  15:30:00          3    MS
#
# ...

# %%
dixie_alley_1950_1989.to_csv('../data/dixie_alley_1950_1989.csv')

# %%
torn_1990_2021 = pd.read_csv('../data/1990-2021_torn.csv')
torn_1990_2021
# Out:
#        tornado_number  year  month  day        date      time  time_zone  \
# 0                   1  1990      1   14  1990-01-14  05:30:00          3
# 1                   2  1990      1   16  1990-01-16  23:20:00          3
# 2                   3  1990      1   19  1990-01-19  11:30:00          3
# 3                   4  1990      1   19  1990-01-19  15:40:00          3
# 4                   5  1990      1   19  1990-01-19  18:10:00          3
# ...               ...   ...    ...  ...         ...       ...        ...
# 39995          620933  2021     12   30  2021-12-30  15:32:00          3
# 39996          620934  2021     12   30  2021-12-30  17:09:00          3
# 39997          620935  2021     12   31  2021-12-31  14:49:00          3
# 39998          620936  2021     12   31  2021-12-31  16:32:00          3
# 39999          620937  2021     12   31  2021-12-31  16:39:00          3
#
#       state  state_fips  state_number  ...  length_miles  width  \
# ...

# %%
torn_alley_1990_2021 = torn_1990_2021.loc[(torn_1990_2021.state == 'OK') |(torn_1990_2021.state == 'KS') 
|(torn_1990_2021.state == 'NE') |(torn_1990_2021.state == 'TX') |(torn_1990_2021.state == 'MO') 
|(torn_1990_2021.state == 'IA') | (torn_1990_2021.state == 'SD') |(torn_1990_2021.state == 'MN')].reset_index(drop=True)
torn_alley_1990_2021
# Out:
#        tornado_number  year  month  day        date      time  time_zone  \
# 0                   3  1990      1   19  1990-01-19  11:30:00          3
# 1                   4  1990      1   19  1990-01-19  15:40:00          3
# 2                   5  1990      1   19  1990-01-19  18:10:00          3
# 3                  12  1990      2    1  1990-02-01  17:23:00          3
# 4                  26  1990      2    9  1990-02-09  17:16:00          3
# ...               ...   ...    ...  ...         ...       ...        ...
# 16605          620909  2021     12   15  2021-12-15  20:06:00          3
# 16606          620910  2021     12   15  2021-12-15  20:10:00          3
# 16607          620911  2021     12   15  2021-12-15  20:17:00          3
# 16608          620911  2021     12   15  2021-12-15  20:17:00          3
# 16609          620921  2021     12   18  2021-12-18  10:47:00          3
#
#       state  state_fips  state_number  ...  length_miles  width  \
# ...

# %%
torn_alley_1990_2021.to_csv('../data/torn_alley_1990_2021.csv')

# %%
torn_water_1985_2 = torn_alley_1990_2021.loc[(torn_alley_1990_2021.year < 1995)]
torn_water_1985_2.reset_index(drop = True)
# Out:
#       tornado_number  year  month  day        date      time  time_zone state  \
# 0                  3  1990      1   19  1990-01-19  11:30:00          3    TX
# 1                  4  1990      1   19  1990-01-19  15:40:00          3    TX
# 2                  5  1990      1   19  1990-01-19  18:10:00          3    TX
# 3                 12  1990      2    1  1990-02-01  17:23:00          3    TX
# 4                 26  1990      2    9  1990-02-09  17:16:00          3    TX
# ...              ...   ...    ...  ...         ...       ...        ...   ...
# 2701            1046  1994     11    4  1994-11-04  17:50:00          3    TX
# 2702            1047  1994     11    4  1994-11-04  22:00:00          3    TX
# 2703            1048  1994     11    5  1994-11-05  06:45:00          3    TX
# 2704            1050  1994     11    5  1994-11-05  18:30:00          3    TX
# 2705            1059  1994     11   20  1994-11-20  06:00:00          3    TX
#
# ...

# %%
torn_water_1985 = pd.merge(torn_water_1985_1, torn_water_1985_2,
        on=['tornado_number','year','month','day','date','time','time_zone','state','state_fips','state_number','ef_scale','injuries','fatalities','loss','crop_loss','start_lat','start_lon','end_lat','end_lon','length_miles','width','num_states_affected','state_num','tornado_segment','f1','f2','f3','f4','est_fscale'], how ='outer')
torn_water_1985 = torn_water_1985.sort_values(by='year').reset_index(drop = True)
torn_water_1985
# Out:
#       tornado_number  year  month  day        date      time  time_zone state  \
# 0                  6  1985      2   22  1985-02-22  02:15:00          3    OK
# 1                366  1985      6    2  1985-06-02  18:25:00          3    OK
# 2                365  1985      6    2  1985-06-02  18:20:00          3    OK
# 3                364  1985      6    1  1985-06-01  20:10:00          3    TX
# 4                330  1985      5   30  1985-05-30  21:22:00          3    IA
# ...              ...   ...    ...  ...         ...       ...        ...   ...
# 4235             323  1994      5    9  1994-05-09  16:40:00          3    TX
# 4236             322  1994      5    9  1994-05-09  07:10:00          3    TX
# 4237             321  1994      5    6  1994-05-06  23:53:00          3    OK
# 4238             333  1994      5   11  1994-05-11  17:30:00          3    TX
# 4239            1059  1994     11   20  1994-11-20  06:00:00          3    TX
#
# ...

# %%
torn_water_1985.to_csv('../data/torn_water_1985.csv')

# %%
torn_water_1995 = torn_alley_1990_2021.loc[(torn_alley_1990_2021.year > 1994)&(torn_alley_1990_2021.year<2005)]
torn_water_1995.reset_index(drop = True)
# Out:
#       tornado_number  year  month  day        date      time  time_zone state  \
# 0                 14  1995      1   12  1995-01-12  13:54:00          3    TX
# 1                 15  1995      1   12  1995-01-12  19:48:00          3    TX
# 2                 16  1995      1   12  1995-01-12  20:03:00          3    TX
# 3                 17  1995      1   12  1995-01-12  21:30:00          3    TX
# 4                 18  1995      1   12  1995-01-12  23:42:00          3    TX
# ...              ...   ...    ...  ...         ...       ...        ...   ...
# 5508             707  2004     11   23  2004-11-23  21:20:00          3    TX
# 5509             612  2004     11   23  2004-11-23  22:00:00          3    TX
# 5510            1689  2004     11   23  2004-11-23  22:05:00          3    TX
# 5511             718  2004     12    6  2004-12-06  14:20:00          3    TX
# 5512             719  2004     12    6  2004-12-06  14:43:00          3    TX
#
# ...

# %%
torn_water_1995.to_csv('../data/torn_water_1995.csv')

# %%
torn_water_2005 = torn_alley_1990_2021.loc[(torn_alley_1990_2021.year > 2004)&(torn_alley_1990_2021.year<2018)]
torn_water_2005.reset_index(drop = True)
# Out:
#       tornado_number  year  month  day        date      time  time_zone state  \
# 0                  5  2005      1   12  2005-01-12  20:56:00          3    MO
# 1                  3  2005      1   12  2005-01-12  21:30:00          3    MO
# 2                  4  2005      1   12  2005-01-12  21:50:00          3    MO
# 3                671  2005      3   21  2005-03-21  13:26:00          3    KS
# 4                672  2005      3   21  2005-03-21  13:40:00          3    KS
# ...              ...   ...    ...  ...         ...       ...        ...   ...
# 6592          615888  2017     12    4  2017-12-04  17:26:00          3    IA
# 6593          615889  2017     12    4  2017-12-04  18:18:00          3    MO
# 6594          615890  2017     12   19  2017-12-19  18:53:00          3    TX
# 6595          615891  2017     12   19  2017-12-19  19:31:00          3    TX
# 6596          615893  2017     12   20  2017-12-20  01:37:00          3    TX
#
# ...

# %%
torn_water_2005.to_csv('../data/torn_water_2005.csv')

# %%
dixie_alley_1990_2021 = torn_1990_2021.loc[(torn_1990_2021.state == 'AR') |(torn_1990_2021.state == 'LA') 
|(torn_1990_2021.state == 'TN') |(torn_1990_2021.state == 'AL') |(torn_1990_2021.state == 'GA') 
|(torn_1990_2021.state == 'MS')].reset_index(drop=True)
dixie_alley_1990_2021
# Out:
#       tornado_number  year  month  day        date      time  time_zone state  \
# 0                  6  1990      1   24  1990-01-24  10:00:00          3    LA
# 1                  7  1990      1   25  1990-01-25  05:50:00          3    AL
# 2                  8  1990      1   25  1990-01-25  11:15:00          3    GA
# 3                  9  1990      1   29  1990-01-29  14:43:00          3    GA
# 4                 13  1990      2    2  1990-02-02  17:40:00          3    LA
# ...              ...   ...    ...  ...         ...       ...        ...   ...
# 7859          620933  2021     12   30  2021-12-30  15:32:00          3    GA
# 7860          620934  2021     12   30  2021-12-30  17:09:00          3    GA
# 7861          620935  2021     12   31  2021-12-31  14:49:00          3    AL
# 7862          620936  2021     12   31  2021-12-31  16:32:00          3    GA
# 7863          620937  2021     12   31  2021-12-31  16:39:00          3    GA
#
# ...

# %%
dixie_alley_1990_2021.to_csv('../data/dixie_alley_1990_2021.csv')

# %%
dixie_water_1985_2 = dixie_alley_1990_2021.loc[(dixie_alley_1990_2021.year < 1995)]
dixie_water_1985_2.reset_index(drop = True)
# Out:
#      tornado_number  year  month  day        date      time  time_zone state  \
# 0                 6  1990      1   24  1990-01-24  10:00:00          3    LA
# 1                 7  1990      1   25  1990-01-25  05:50:00          3    AL
# 2                 8  1990      1   25  1990-01-25  11:15:00          3    GA
# 3                 9  1990      1   29  1990-01-29  14:43:00          3    GA
# 4                13  1990      2    2  1990-02-02  17:40:00          3    LA
# ..              ...   ...    ...  ...         ...       ...        ...   ...
# 685            1076  1994     11   27  1994-11-27  20:40:00          3    MS
# 686            1077  1994     11   27  1994-11-27  22:15:00          3    MS
# 687            1078  1994     11   28  1994-11-28  00:30:00          3    AL
# 688            1079  1994     12    3  1994-12-03  16:53:00          3    MS
# 689            1080  1994     12    3  1994-12-03  21:30:00          3    AL
#
# ...

# %%
dixie_water_1985 = pd.merge(dixie_water_1985_1, dixie_water_1985_2,
        on=['tornado_number','year','month','day','date','time','time_zone','state','state_fips','state_number','ef_scale','injuries','fatalities','loss','crop_loss','start_lat','start_lon','end_lat','end_lon','length_miles','width','num_states_affected','state_num','tornado_segment','f1','f2','f3','f4','est_fscale'], how ='outer')
dixie_water_1985 = dixie_water_1985.sort_values(by='year').reset_index(drop = True)
dixie_water_1985
# Out:
#       tornado_number  year  month  day        date      time  time_zone state  \
# 0                  2  1985      1   31  1985-01-31  16:52:00          3    AL
# 1                563  1985      8   16  1985-08-16  16:00:00          3    TN
# 2                562  1985      8   16  1985-08-16  15:30:00          3    AL
# 3                561  1985      8   16  1985-08-16  15:30:00          3    TN
# 4                560  1985      8   16  1985-08-16  14:20:00          3    AL
# ...              ...   ...    ...  ...         ...       ...        ...   ...
# 1278             231  1994      4   26  1994-04-26  18:50:00          3    MS
# 1279             252  1994      4   27  1994-04-27  12:15:00          3    TN
# 1280             255  1994      4   27  1994-04-27  13:40:00          3    TN
# 1281             609  1994      6   26  1994-06-26  18:00:00          3    TN
# 1282            1080  1994     12    3  1994-12-03  21:30:00          3    AL
#
# ...

# %%
dixie_water_1985.to_csv('../data/dixie_water_1985.csv')

# %%
dixie_water_1995 = dixie_alley_1990_2021.loc[(dixie_alley_1990_2021.year > 1994)&(dixie_alley_1990_2021.year<2005)]
dixie_water_1995.reset_index(drop = True)
# Out:
#       tornado_number  year  month  day        date      time  time_zone state  \
# 0                  1  1995      1    6  1995-01-06  09:40:00          3    LA
# 1                  2  1995      1    6  1995-01-06  11:05:00          3    LA
# 2                  3  1995      1    6  1995-01-06  11:10:00          3    LA
# 3                 11  1995      1    7  1995-01-07  02:25:00          3    LA
# 4                 27  1995      1   18  1995-01-18  13:55:00          3    LA
# ...              ...   ...    ...  ...         ...       ...        ...   ...
# 2136             721  2004     12    7  2004-12-07  04:02:00          3    AL
# 2137             722  2004     12    9  2004-12-09  01:25:00          3    LA
# 2138             695  2004     12    9  2004-12-09  04:06:00          3    MS
# 2139             650  2004     12    9  2004-12-09  05:27:00          3    MS
# 2140              46  2004     12    9  2004-12-09  05:38:00          3    MS
#
# ...

# %%
dixie_water_1995.to_csv('../data/dixie_water_1995.csv')

# %%
dixie_water_2005 = dixie_alley_1990_2021.loc[(dixie_alley_1990_2021.year > 2004)&(dixie_alley_1990_2021.year<2018)]
dixie_water_2005.reset_index(drop = True)
# Out:
#       tornado_number  year  month  day        date      time  time_zone state  \
# 0                619  2005      1    7  2005-01-07  17:17:00          3    MS
# 1                620  2005      1    7  2005-01-07  18:55:00          3    MS
# 2                 37  2005      1    7  2005-01-07  20:10:00          3    MS
# 3                621  2005      1    7  2005-01-07  21:35:00          3    MS
# 4                622  2005      1    7  2005-01-07  21:53:00          3    MS
# ...              ...   ...    ...  ...         ...       ...        ...   ...
# 3666          615894  2017     12   20  2017-12-20  01:59:00          3    LA
# 3667          615895  2017     12   20  2017-12-20  02:17:00          3    LA
# 3668          615896  2017     12   20  2017-12-20  06:39:00          3    MS
# 3669          615897  2017     12   20  2017-12-20  10:40:00          3    AL
# 3670          615898  2017     12   20  2017-12-20  12:15:00          3    GA
#
# ...

# %%
dixie_water_2005.to_csv('../data/dixie_water_2005.csv')

# %%
torn_dixie_1965 = pd.merge(torn_water_1965, dixie_water_1965,
        on=['tornado_number','year','month','day','date','time','time_zone','state','state_fips','state_number','ef_scale','injuries','fatalities','loss','crop_loss','start_lat','start_lon','end_lat','end_lon','length_miles','width','num_states_affected','state_num','tornado_segment','f1','f2','f3','f4','est_fscale'], how ='outer')
torn_dixie_1965 = torn_dixie_1965.sort_values(by='year').reset_index(drop = True)
torn_dixie_1965
# Out:
#       tornado_number  year  month  day        date      time  time_zone state  \
# 0                  3  1965      1   21  1965-01-21  23:00:00          3    TX
# 1                656  1965      7    8  1965-07-08  21:30:00          3    IA
# 2                657  1965      7    9  1965-07-09  04:00:00          3    MO
# 3                658  1965      7    9  1965-07-09  15:00:00          3    KS
# 4                670  1965      7   12  1965-07-12  18:40:00          3    SD
# ...              ...   ...    ...  ...         ...       ...        ...   ...
# 5147             542  1974      6    7  1974-06-07  19:45:00          3    TX
# 5148             539  1974      6    7  1974-06-07  18:50:00          3    TX
# 5149             534  1974      6    7  1974-06-07  16:30:00          3    TX
# 5150             525  1974      6    6  1974-06-06  21:30:00          3    OK
# 5151             944  1974     12   19  1974-12-19  16:30:00          3    AL
#
# ...

# %%
torn_dixie_1965.to_csv('../data/torn_dixie_1965.csv')

# %%
torn_dixie_1975 = pd.merge(torn_water_1975, dixie_water_1975,
        on=['tornado_number','year','month','day','date','time','time_zone','state','state_fips','state_number','ef_scale','injuries','fatalities','loss','crop_loss','start_lat','start_lon','end_lat','end_lon','length_miles','width','num_states_affected','state_num','tornado_segment','f1','f2','f3','f4','est_fscale'], how ='outer')
torn_dixie_1975 = torn_dixie_1975.sort_values(by='year').reset_index(drop = True)
torn_dixie_1975
# Out:
#       tornado_number  year  month  day        date      time  time_zone state  \
# 0                  4  1975      1    9  1975-01-09  22:30:00          3    OK
# 1                691  1975      7    7  1975-07-07  16:25:00          3    AR
# 2                721  1975      7   17  1975-07-17  10:05:00          3    LA
# 3                762  1975      8    5  1975-08-05  12:59:00          3    LA
# 4                763  1975      8    5  1975-08-05  12:59:00          3    LA
# ...              ...   ...    ...  ...         ...       ...        ...   ...
# 5346             856  1984     10   18  1984-10-18  19:30:00          3    MO
# 5347             858  1984     10   20  1984-10-20  16:00:00          3    TX
# 5348             861  1984     10   22  1984-10-22  00:30:00          3    TX
# 5349             812  1984      9    9  1984-09-09  16:14:00          3    IA
# 5350             902  1984     11   10  1984-11-10  17:50:00          3    GA
#
# ...

# %%
torn_dixie_1975.to_csv('../data/torn_dixie_1975.csv')

# %%
torn_dixie_1985 = pd.merge(torn_water_1985, dixie_water_1985,
        on=['tornado_number','year','month','day','date','time','time_zone','state','state_fips','state_number','ef_scale','injuries','fatalities','loss','crop_loss','start_lat','start_lon','end_lat','end_lon','length_miles','width','num_states_affected','state_num','tornado_segment','f1','f2','f3','f4','est_fscale'], how ='outer')
torn_dixie_1985 = torn_dixie_1985.sort_values(by='year').reset_index(drop = True)
torn_dixie_1985
# Out:
#       tornado_number  year  month  day        date      time  time_zone state  \
# 0                  6  1985      2   22  1985-02-22  02:15:00          3    OK
# 1                149  1985      4   27  1985-04-27  17:32:00          3    TX
# 2                205  1985      5   10  1985-05-10  15:50:00          3    KS
# 3                150  1985      4   27  1985-04-27  18:14:00          3    TX
# 4                151  1985      4   28  1985-04-28  08:23:00          3    TX
# ...              ...   ...    ...  ...         ...       ...        ...   ...
# 5518             803  1994      7   25  1994-07-25  17:35:00          3    NE
# 5519             834  1994      7   31  1994-07-31  16:20:00          3    KS
# 5520             835  1994      7   31  1994-07-31  17:26:00          3    IA
# 5521             845  1994      8    3  1994-08-03  16:20:00          3    KS
# 5522            1080  1994     12    3  1994-12-03  21:30:00          3    AL
#
# ...

# %%
torn_dixie_1985.to_csv('../data/torn_dixie_1985.csv')

# %%
torn_dixie_1995 = pd.merge(torn_water_1995, dixie_water_1995,
        on=['tornado_number','year','month','day','date','time','time_zone','state','state_fips','state_number','ef_scale','injuries','fatalities','loss','crop_loss','start_lat','start_lon','end_lat','end_lon','length_miles','width','num_states_affected','state_num','tornado_segment','f1','f2','f3','f4','est_fscale'], how ='outer')
torn_dixie_1995 = torn_dixie_1995.sort_values(by='year').reset_index(drop = True)
torn_dixie_1995
# Out:
#       tornado_number  year  month  day        date      time  time_zone state  \
# 0                 14  1995      1   12  1995-01-12  13:54:00          3    TX
# 1               1001  1995      8    2  1995-08-02  17:30:00          3    MN
# 2               1009  1995      8    4  1995-08-04  17:35:00          3    IA
# 3               1011  1995      8    5  1995-08-05  13:22:00          3    NE
# 4               1012  1995      8    5  1995-08-05  14:22:00          3    NE
# ...              ...   ...    ...  ...         ...       ...        ...   ...
# 7649             992  2004      5   24  2004-05-24  15:15:00          3    KS
# 7650            1202  2004      5   24  2004-05-24  15:16:00          3    NE
# 7651             993  2004      5   24  2004-05-24  15:18:00          3    KS
# 7652            1052  2004      5   24  2004-05-24  14:35:00          3    MO
# 7653              46  2004     12    9  2004-12-09  05:38:00          3    MS
#
# ...

# %%
torn_dixie_1995.to_csv('../data/torn_dixie_1995.csv')

# %%
torn_dixie_2005 = pd.merge(torn_water_2005, dixie_water_2005,
        on=['tornado_number','year','month','day','date','time','time_zone','state','state_fips','state_number','ef_scale','injuries','fatalities','loss','crop_loss','start_lat','start_lon','end_lat','end_lon','length_miles','width','num_states_affected','state_num','tornado_segment','f1','f2','f3','f4','est_fscale'], how ='outer')
torn_dixie_2005 = torn_dixie_2005.sort_values(by='year').reset_index(drop = True)
torn_dixie_2005
# Out:
#        tornado_number  year  month  day        date      time  time_zone  \
# 0                   5  2005      1   12  2005-01-12  20:56:00          3
# 1                1226  2005     11   15  2005-11-15  18:25:00          3
# 2                1228  2005     11   15  2005-11-15  18:15:00          3
# 3                 528  2005     11   15  2005-11-15  18:05:00          3
# 4                 527  2005     11   15  2005-11-15  18:02:00          3
# ...               ...   ...    ...  ...         ...       ...        ...
# 10263          615033  2017      4   29  2017-04-29  17:08:00          3
# 10264          615034  2017      4   29  2017-04-29  17:32:00          3
# 10265          615035  2017      4   29  2017-04-29  18:13:00          3
# 10266          615027  2017      4   29  2017-04-29  15:17:00          3
# 10267          615898  2017     12   20  2017-12-20  12:15:00          3
#
#       state  state_fips  state_number  ...  length_miles   width  \
# ...

# %%
torn_dixie_2005.to_csv('../data/torn_dixie_2005.csv')

# %%
hail_1950_1989 = pd.read_csv('../data/1950-1989_hail.csv')
hail_1950_1989
# Out:
#       tornado_number  year  month  day        date      time  time_zone state  \
# 0                  1  1950      1    3  1950-01-03  11:00:00          3    MO
# 1                  1  1950      1    3  1950-01-03  11:00:00          3    MO
# 2                  1  1950      1    3  1950-01-03  11:10:00          3    IL
# 3                  2  1950      1    3  1950-01-03  11:55:00          3    IL
# 4                  3  1950      1    3  1950-01-03  16:00:00          3    OH
# ...              ...   ...    ...  ...         ...       ...        ...   ...
# 4900             600  1959     11    4  1959-11-04  15:20:00          3    AK
# 4901             601  1959     11    4  1959-11-04  16:15:00          3    MS
# 4902             602  1959     11   22  1959-11-22  19:30:00          3    MS
# 4903             603  1959     12   11  1959-12-11  15:45:00          3    MO
# 4904             604  1959     12   26  1959-12-26  17:45:00          3    KS
#
# ...

# %%
hail_1950_1989_tornalley = hail_1950_1989.loc[(hail_1950_1989.state == 'OK') |(hail_1950_1989.state == 'KS') 
|(hail_1950_1989.state == 'NE') |(hail_1950_1989.state == 'TX') |(hail_1950_1989.state == 'MO') 
|(hail_1950_1989.state == 'IA') | (hail_1950_1989.state == 'SD') |(hail_1950_1989.state == 'MN')].reset_index(drop=True)
hail_1950_1989_tornalley
# Out:
#       tornado_number  year  month  day        date      time  time_zone state  \
# 0                  1  1950      1    3  1950-01-03  11:00:00          3    MO
# 1                  1  1950      1    3  1950-01-03  11:00:00          3    MO
# 2                  5  1950      1   25  1950-01-25  19:30:00          3    MO
# 3                  7  1950      1   26  1950-01-26  18:00:00          3    TX
# 4                  8  1950      2   11  1950-02-11  13:10:00          3    TX
# ...              ...   ...    ...  ...         ...       ...        ...   ...
# 2569             597  1959     11    3  1959-11-03  21:00:00          3    TX
# 2570             598  1959     11    4  1959-11-04  01:00:00          3    TX
# 2571             599  1959     11    4  1959-11-04  01:25:00          3    TX
# 2572             603  1959     12   11  1959-12-11  15:45:00          3    MO
# 2573             604  1959     12   26  1959-12-26  17:45:00          3    KS
#
# ...

# %%
hail_1950_1989_tornalley.to_csv('../data/hail_1950_1989_tornalley.csv')

# %%
hail_1950_1989_dixiealley = hail_1950_1989.loc[(hail_1950_1989.state == 'AR') |(hail_1950_1989.state == 'LA') 
|(hail_1950_1989.state == 'TN') |(hail_1950_1989.state == 'AL') |(hail_1950_1989.state == 'GA') 
|(hail_1950_1989.state == 'MS')].reset_index(drop=True)
hail_1950_1989_dixiealley
# Out:
#      tornado_number  year  month  day        date      time  time_zone state  \
# 0                 4  1950      1   13  1950-01-13  05:25:00          3    AR
# 1                16  1950      2   12  1950-02-12  12:00:00          3    MS
# 2                17  1950      2   12  1950-02-12  12:00:00          3    MS
# 3                19  1950      2   12  1950-02-12  12:30:00          3    AR
# 4                20  1950      2   12  1950-02-12  13:00:00          3    LA
# ..              ...   ...    ...  ...         ...       ...        ...   ...
# 789             543  1959      9   26  1959-09-26  18:20:00          3    AR
# 790             543  1959      9   26  1959-09-26  18:20:00          3    AR
# 791             543  1959      9   26  1959-09-26  19:05:00          3    TN
# 792             601  1959     11    4  1959-11-04  16:15:00          3    MS
# 793             602  1959     11   22  1959-11-22  19:30:00          3    MS
#
# ...

# %%
hail_1950_1989_dixiealley.to_csv('../data/hail_1950_1989_dixiealley.csv')

# %%
hail_1990_2021 = pd.read_csv('../data/1990-2021_hail.csv')
hail_1990_2021
# Out:
#         tornado_number  year  month  day        date      time  time_zone  \
# 0                    1  1990      1    3  1990-01-03  17:25:00          3
# 1                    2  1990      1    3  1990-01-03  17:40:00          3
# 2                    3  1990      1    5  1990-01-05  21:25:00          3
# 3                    4  1990      1   16  1990-01-16  11:56:00          3
# 4                    5  1990      1   16  1990-01-16  12:05:00          3
# ...                ...   ...    ...  ...         ...       ...        ...
# 329731          663777  2021     12   30  2021-12-30  15:45:00          3
# 329732          663778  2021     12   30  2021-12-30  16:05:00          3
# 329733          663779  2021     12   30  2021-12-30  16:10:00          3
# 329734          663780  2021     12   30  2021-12-30  16:42:00          3
# 329735          663781  2021     12   30  2021-12-30  17:35:00          3
#
#        state  state_fips  state_number  ...  length_miles  width  \
# ...

# %%
hail_1990_2021_tornalley = hail_1990_2021.loc[(hail_1990_2021.state == 'OK') |(hail_1990_2021.state == 'KS') 
|(hail_1990_2021.state == 'NE') |(hail_1990_2021.state == 'TX') |(hail_1990_2021.state == 'MO') 
|(hail_1990_2021.state == 'IA') | (hail_1990_2021.state == 'SD') |(hail_1990_2021.state == 'MN')].reset_index(drop=True)
hail_1990_2021_tornalley
# Out:
#         tornado_number  year  month  day        date      time  time_zone  \
# 0                    1  1990      1    3  1990-01-03  17:25:00          3
# 1                    2  1990      1    3  1990-01-03  17:40:00          3
# 2                    4  1990      1   16  1990-01-16  11:56:00          3
# 3                    5  1990      1   16  1990-01-16  12:05:00          3
# 4                    6  1990      1   16  1990-01-16  13:07:00          3
# ...                ...   ...    ...  ...         ...       ...        ...
# 168667          663749  2021     12   18  2021-12-18  09:58:00          3
# 168668          663750  2021     12   18  2021-12-18  10:15:00          3
# 168669          663751  2021     12   18  2021-12-18  10:16:00          3
# 168670          663752  2021     12   18  2021-12-18  10:30:00          3
# 168671          663753  2021     12   18  2021-12-18  11:12:00          3
#
#        state  state_fips  state_number  ...  length_miles  width  \
# ...

# %%
hail_1990_2021_tornalley.to_csv('../data/hail_1990_2021_tornalley.csv')

# %%
hail_1990_2021_dixiealley = hail_1990_2021.loc[(hail_1990_2021.state == 'AR') |(hail_1990_2021.state == 'LA') 
|(hail_1990_2021.state == 'TN') |(hail_1990_2021.state == 'AL') |(hail_1990_2021.state == 'GA') 
|(hail_1990_2021.state == 'MS')].reset_index(drop=True)
hail_1990_2021_dixiealley
# Out:
#        tornado_number  year  month  day        date      time  time_zone  \
# 0                   3  1990      1    5  1990-01-05  21:25:00          3
# 1                  32  1990      1   17  1990-01-17  21:00:00          3
# 2                  35  1990      1   17  1990-01-17  23:00:00          3
# 3                  36  1990      1   17  1990-01-17  23:30:00          3
# 4                  38  1990      1   19  1990-01-19  17:15:00          3
# ...               ...   ...    ...  ...         ...       ...        ...
# 40216          663771  2021     12   30  2021-12-30  15:14:00          3
# 40217          663773  2021     12   30  2021-12-30  15:15:00          3
# 40218          663774  2021     12   30  2021-12-30  15:20:00          3
# 40219          663775  2021     12   30  2021-12-30  15:20:00          3
# 40220          663776  2021     12   30  2021-12-30  15:25:00          3
#
#       state  state_fips  state_number  ...  length_miles  width  \
# ...

# %%
hail_1990_2021_dixiealley.to_csv('../data/hail_1990_2021_dixiealley.csv')

# %%
wind_1950_1989 = pd.read_csv('../data/1950-1989_wind.csv')
wind_1950_1989
# Out:
#        tornado_number  year  month  day        date      time  time_zone  \
# 0                   1  1955      2    1  1955-02-01  13:45:00          3
# 1                   2  1955      2    5  1955-02-05  08:00:00          3
# 2                   3  1955      2   11  1955-02-11  16:00:00          3
# 3                   4  1955      3    1  1955-03-01  02:00:00          3
# 4                   5  1955      3    1  1955-03-01  02:00:00          3
# ...               ...   ...    ...  ...         ...       ...        ...
# 71626            5706  1989     11   28  1989-11-28  00:40:00          3
# 71627            5707  1989     11   28  1989-11-28  01:30:00          3
# 71628            5708  1989     11   28  1989-11-28  01:30:00          3
# 71629            5709  1989     12    8  1989-12-08  00:00:00          3
# 71630            5710  1989     12    8  1989-12-08  05:00:00          3
#
#       state  state_fips  state_number  ...  length_miles  width  \
# ...

# %%
wind_1950_1989_tornalley = wind_1950_1989.loc[(wind_1950_1989.state == 'OK') |(wind_1950_1989.state == 'KS') 
|(wind_1950_1989.state == 'NE') |(wind_1950_1989.state == 'TX') |(wind_1950_1989.state == 'MO') 
|(wind_1950_1989.state == 'IA') | (wind_1950_1989.state == 'SD') |(wind_1950_1989.state == 'MN')].reset_index(drop=True)
wind_1950_1989_tornalley
# Out:
#        tornado_number  year  month  day        date      time  time_zone  \
# 0                  20  1955      3   20  1955-03-20  15:00:00          3
# 1                  22  1955      3   20  1955-03-20  16:00:00          3
# 2                  24  1955      3   20  1955-03-20  18:15:00          3
# 3                  26  1955      3   20  1955-03-20  19:55:00          3
# 4                  44  1955      3   31  1955-03-31  14:15:00          3
# ...               ...   ...    ...  ...         ...       ...        ...
# 25489            5176  1989     10   29  1989-10-29  18:50:00          3
# 25490            5177  1989     10   29  1989-10-29  21:20:00          3
# 25491            5178  1989     10   30  1989-10-30  04:55:00          3
# 25492            5212  1989     11   15  1989-11-15  04:27:00          3
# 25493            5213  1989     11   15  1989-11-15  04:43:00          3
#
#       state  state_fips  state_number  ...  length_miles  width  \
# ...

# %%
wind_1950_1989_tornalley.to_csv('../data/wind_1950_1989_tornalley.csv')

# %%
wind_1950_1989_dixiealley = wind_1950_1989.loc[(wind_1950_1989.state == 'AR') |(wind_1950_1989.state == 'LA') 
|(wind_1950_1989.state == 'TN') |(wind_1950_1989.state == 'AL') |(wind_1950_1989.state == 'GA') 
|(wind_1950_1989.state == 'MS')].reset_index(drop=True)
wind_1950_1989_dixiealley
# Out:
#        tornado_number  year  month  day        date      time  time_zone  \
# 0                   1  1955      2    1  1955-02-01  13:45:00          3
# 1                   2  1955      2    5  1955-02-05  08:00:00          3
# 2                   7  1955      3    1  1955-03-01  06:24:00          3
# 3                   8  1955      3    1  1955-03-01  06:55:00          3
# 4                  18  1955      3   20  1955-03-20  14:30:00          3
# ...               ...   ...    ...  ...         ...       ...        ...
# 13506            5692  1989     11   22  1989-11-22  21:30:00          3
# 13507            5694  1989     11   27  1989-11-27  18:00:00          3
# 13508            5707  1989     11   28  1989-11-28  01:30:00          3
# 13509            5708  1989     11   28  1989-11-28  01:30:00          3
# 13510            5710  1989     12    8  1989-12-08  05:00:00          3
#
#       state  state_fips  state_number  ...  length_miles  width  \
# ...

# %%
wind_1950_1989_dixiealley.to_csv('../data/wind_1950_1989_dixiealley.csv')

# %%
wind_1990_2021 = pd.read_csv('../data/1990-2021_wind.csv')
wind_1990_2021
# Out:
# C:\Users\eykin\AppData\Local\Temp\ipykernel_38084\3620153038.py:1: DtypeWarning: Columns (28) have mixed types. Specify dtype option on import or set low_memory=False.
#   wind_1990_2021 = pd.read_csv('../data/1990-2021_wind.csv')
#         tornado_number  year  month  day        date      time  time_zone  \
# 0                    1  1990      1    1  1990-01-01  04:57:00          3
# 1                    2  1990      1    2  1990-01-02  19:30:00          3
# 2                    3  1990      1    3  1990-01-03  17:45:00          3
# 3                    4  1990      1   16  1990-01-16  04:50:00          3
# 4                    5  1990      1   17  1990-01-17  03:30:00          3
# ...                ...   ...    ...  ...         ...       ...        ...
# 406490          713605  2021     12   30  2021-12-30  15:27:00          3
# 406491          713606  2021     12   30  2021-12-30  16:20:00          3
# 406492          713607  2021     12   30  2021-12-30  16:22:00          3
# ...

# %%
wind_1990_2021_tornalley = wind_1990_2021.loc[(wind_1990_2021.state == 'OK') |(wind_1990_2021.state == 'KS') 
|(wind_1990_2021.state == 'NE') |(wind_1990_2021.state == 'TX') |(wind_1990_2021.state == 'MO') 
|(wind_1990_2021.state == 'IA') | (wind_1990_2021.state == 'SD') |(wind_1990_2021.state == 'MN')].reset_index(drop=True)
wind_1990_2021_tornalley
# Out:
#         tornado_number  year  month  day        date      time  time_zone  \
# 0                    3  1990      1    3  1990-01-03  17:45:00          3
# 1                    5  1990      1   17  1990-01-17  03:30:00          3
# 2                    6  1990      1   17  1990-01-17  04:10:00          3
# 3                    7  1990      1   17  1990-01-17  04:10:00          3
# 4                    8  1990      1   17  1990-01-17  07:30:00          3
# ...                ...   ...    ...  ...         ...       ...        ...
# 113159          713541  2021     12   17  2021-12-17  16:45:00          3
# 113160          713542  2021     12   17  2021-12-17  17:05:00          3
# 113161          713543  2021     12   18  2021-12-18  10:30:00          3
# 113162          713544  2021     12   18  2021-12-18  10:51:00          3
# 113163          713545  2021     12   18  2021-12-18  12:52:00          3
#
#        state  state_fips  state_number  ...  length_miles  width  \
# ...

# %%
wind_1990_2021_tornalley.to_csv('../data/wind_1990_2021_tornalley.csv')

# %%
wind_1990_2021_dixiealley = wind_1990_2021.loc[(wind_1990_2021.state == 'AR') |(wind_1990_2021.state == 'LA') 
|(wind_1990_2021.state == 'TN') |(wind_1990_2021.state == 'AL') |(wind_1990_2021.state == 'GA') 
|(wind_1990_2021.state == 'MS')].reset_index(drop=True)
wind_1990_2021_dixiealley
# Out:
#        tornado_number  year  month  day        date      time  time_zone  \
# 0                   4  1990      1   16  1990-01-16  04:50:00          3
# 1                  13  1990      1   17  1990-01-17  10:00:00          3
# 2                  15  1990      1   17  1990-01-17  19:58:00          3
# 3                  16  1990      1   17  1990-01-17  20:30:00          3
# 4                  17  1990      1   17  1990-01-17  20:31:00          3
# ...               ...   ...    ...  ...         ...       ...        ...
# 78745          713605  2021     12   30  2021-12-30  15:27:00          3
# 78746          713606  2021     12   30  2021-12-30  16:20:00          3
# 78747          713607  2021     12   30  2021-12-30  16:22:00          3
# 78748          713608  2021     12   30  2021-12-30  16:23:00          3
# 78749          713609  2021     12   30  2021-12-30  16:25:00          3
#
#       state  state_fips  state_number  ...  length_miles  width  \
# ...

# %%
wind_1990_2021_dixiealley.to_csv('../data/wind_1990_2021_dixiealley.csv')
